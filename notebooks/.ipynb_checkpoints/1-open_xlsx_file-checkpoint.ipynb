# %%
import xlrd
import pandas as pd

# %%
def dateFromFilename(file='20200120_report.xlsx'):
    date = file.replace('_report.xlsx', '').replace('_update.xlsx', '')
    return date

# %%
def openBCCfile(file = '20200120_report.xlsx'):
    date = dateFromFilename(file)
    data_dir = '~/projects/bcc_weekly_reports/data/'
    loc = (data_dir + file)

    print('Opening {}'.format(loc))
    wb = xlrd.open_workbook(loc)
    sheet = wb.sheet_by_name('COA Stats')
#     if '_update' in file:
#         sheet = wb.sheet_by_index(0)
#     else:
#         sheet = wb.sheet_by_index(2)
    print('Rows: {}, Cols: {}'.format(sheet.ncols, sheet.nrows))
    
    return wb, sheet

wb, sheet = openBCCfile(file = '20200120_report.xlsx')
# Out:
# Opening ~/projects/bcc_weekly_reports/data/20200120_report.xlsx
# Rows: 4, Cols: 24

# %%
def importCOAdata(table='totals', file = '20200120_report.xlsx'):
    '''
    Return a df of one of the 3 tables found in the COA weekly report
    '''
    # Which table to import
    if table == 'totals':
        rows = range(1,3)
    elif table == 'product_category':
        rows = range(4,9)
    elif table == 'fail_category':
        rows = range(9,sheet.nrows-1)

    # Create dataframe from table
    data = []
    for row in rows:
        data.append(sheet.row_values(row))
    data_df = pd.DataFrame(data=data[1:], columns=data[0], dtype='int')
    
    # Create date column and make dtype=datetime
    date = dateFromFilename(file)
    data_df['Date'] = pd.to_datetime(date)
    
    return data_df

# %%
totals = importCOAdata(table='totals')
totals
# Out:
#    Certificates of Analysis Received  Tested Batches    Failed Batches  \
# 0                              90793           90793              6124
#
#         Date
# 0 2020-01-20

# %%
product_categories = importCOAdata(table='product_category')
product_categories
# Out:
#                      Tested Batches By Category  Tested Batches    \
# 0                                       Flower:           44108
# 1         Inhalable\n(cartridges, waxes, etc.):           31715
# 2  Other\n(edibles, tinctures, topicals, etc.):           14970
# 3                                        Total:           90793
#
#    Failed Batches By Category       Date
# 0                        2401 2020-01-20
# 1                        2170 2020-01-20
# 2                        1553 2020-01-20
# 3                        6124 2020-01-20

# %%
fail_categories = importCOAdata(table='fail_category')
fail_categories
# Out:
#           *Reasons For Failure    Failed Batches By Category         Date
# 0                Label Claims:                          2379   2020-01-20
# 1                  Pesticides:                          1790   2020-01-20
# 2        Microbial Impurities:                           929   2020-01-20
# 3           Residual Solvents:                           361   2020-01-20
# 4                 Homogeneity:                            36   2020-01-20
# 5            Foreign Material:                            26   2020-01-20
# 6                    Moisture:                            71   2020-01-20
# 7                Heavy Metals:                           541   2020-01-20
# 8              Water Activity:                            51   2020-01-20
# 9                Cannabinoids:                            77   2020-01-20
# 10                 Mycotoxins:                            10   2020-01-20
# 11  Injurious to Human Health:                             2   2020-01-20
# 12                      Total:                          6273   2020-01-20

# %%
from os import listdir
data_dir2 = '../../data/'
files = [f for f in listdir(data_dir2) if '.xlsx' in f]

# %%
dates=[]
for file in files: 
    dates.append(file.replace('_report.xlsx', '').replace('_update.xlsx',''))
dates = sorted(dates)

# %%
dates[:5]
# Out:
# ['20181009', '20181015', '20181022', '20181029', '20181105']

# %%
totals = pd.DataFrame()
product_categories = pd.DataFrame()
fail_categories = pd.DataFrame()

for file in files:
    # Read file, append rows to dataframes, save
    
    # Read file
    wb, sheet = openBCCfile(file=file)
    # Read tables
    totals = totals.append(importCOAdata(table='totals', file=file))
    product_categories = product_categories.append(importCOAdata(table='product_category', file=file))
    fail_categories = fail_categories.append(importCOAdata(table='fail_category', file=file))
# Out:
# Opening ~/projects/bcc_weekly_reports/data/20181113_report.xlsx
# Rows: 4, Cols: 19
# Opening ~/projects/bcc_weekly_reports/data/20190429_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20181203_report.xlsx
# Rows: 4, Cols: 19
# Opening ~/projects/bcc_weekly_reports/data/20190610_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190527_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20191209_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20191007_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190729_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190923_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190603_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20181029_report.xlsx
# Rows: 4, Cols: 19
# Opening ~/projects/bcc_weekly_reports/data/20181210_report.xlsx
# Rows: 4, Cols: 19
# Opening ~/projects/bcc_weekly_reports/data/20190506_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190218_update.xlsx
# Rows: 4, Cols: 22
# Opening ~/projects/bcc_weekly_reports/data/20190204_update.xlsx
# Rows: 4, Cols: 21
# Opening ~/projects/bcc_weekly_reports/data/20190408_report.xlsx
# Rows: 4, Cols: 23
# Opening ~/projects/bcc_weekly_reports/data/20190624_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190513_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20181119_report.xlsx
# Rows: 4, Cols: 19
# Opening ~/projects/bcc_weekly_reports/data/20190701_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20181105_report.xlsx
# Rows: 4, Cols: 19
# Opening ~/projects/bcc_weekly_reports/data/20191216_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190930_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20200120_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190819_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20191014_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190708_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190805_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20191021_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20181022_report.xlsx
# Rows: 4, Cols: 19
# Opening ~/projects/bcc_weekly_reports/data/20191223_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20191028_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190812_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20181009_report.xlsx
# Rows: 4, Cols: 19
# Opening ~/projects/bcc_weekly_reports/data/20190304_update.xlsx
# Rows: 4, Cols: 22
# Opening ~/projects/bcc_weekly_reports/data/20190318_update.xlsx
# Rows: 4, Cols: 22
# Opening ~/projects/bcc_weekly_reports/data/20181015_report.xlsx
# Rows: 4, Cols: 19
# Opening ~/projects/bcc_weekly_reports/data/20190108_report.xlsx
# Rows: 4, Cols: 20
# Opening ~/projects/bcc_weekly_reports/data/20191111_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190909_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20181217_report.xlsx
# Rows: 4, Cols: 20
# Opening ~/projects/bcc_weekly_reports/data/20191104_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190422_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20191230_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20200113_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190916_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20181226_report.xlsx
# Rows: 4, Cols: 20
# Opening ~/projects/bcc_weekly_reports/data/20191202_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190715_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190402_update.xlsx
# Rows: 4, Cols: 22
# Opening ~/projects/bcc_weekly_reports/data/20190122_update.xlsx
# Rows: 4, Cols: 20
# Opening ~/projects/bcc_weekly_reports/data/20200106_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190903_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190826_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190617_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190520_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20191125_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20190722_report.xlsx
# Rows: 4, Cols: 24
# Opening ~/projects/bcc_weekly_reports/data/20181126_report.xlsx
# Rows: 4, Cols: 19
# Opening ~/projects/bcc_weekly_reports/data/20190415_report.xlsx
# Rows: 4, Cols: 24

# %%
# Remove empty columns
del totals['']
del product_categories['']
del fail_categories['']

# %%
totals.to_csv(path_or_buf='../../etl_data/totals.csv', index=False)
product_categories.to_csv(path_or_buf='../../etl_data/product_categories.csv', index=False)
fail_categories.to_csv(path_or_buf='../../etl_data/fail_categories.csv', index=False)

# %%
# Clean up totals df
del totals['Certificates of Analysis Received'] # This column is identical to 'Tested Batches'. Don't need both
totals['Percent Failed'] = 100* totals['Failed Batches'] / totals['Tested Batches']

print('Saving totals.csv...')
totals.to_csv(path_or_buf='../../etl_data/totals.csv', index=False)
# Out:
# Saving totals.csv...

# %%
totals.head()
# Out:
#    Tested Batches  Failed Batches       Date  Percent Failed
# 0           20797            3164 2018-11-13       15.213733
# 0           46503            4679 2019-04-29       10.061716
# 0           23864            3373 2018-12-03       14.134261
# 0           52471            4906 2019-06-10        9.349927
# 0           50811            4831 2019-05-27        9.507784

# %%
product_categories.head()
# Out:
#                      Tested Batches By Category  Tested Batches  \
# 0                                       Flower:           10415
# 1         Inhalable\n(cartridges, waxes, etc.):            6464
# 2  Other\n(edibles, tinctures, topicals, etc.):            3918
# 3                                        Total:           20797
# 0                                       Flower:           23347
#
#   Failed Batches By Category       Date
# 0                       1029 2018-11-13
# 1                       1054 2018-11-13
# 2                       1081 2018-11-13
# 3                       3164 2018-11-13
# 0                       1627 2019-04-29

# %%
# Clean up product_categories df

# Rename Columns
def removeCol(df, column, newname):
    try: 
        df[column]
    except: 
        return df
    else:
        df[newname] = df[column]
        del df[column]
        return df
product_categories = removeCol(product_categories, 'Tested Batches By Category', newname='Category')
product_categories = removeCol(product_categories, 'Failed Batches By Category', newname='Failed Batches')

# Some values has ',' in them and are thus 'objects'
# Convert these to ints
def makeFloat(data):
    valid = '1234567890.' #valid characters for a float
    try: 
        ''.join(filter(lambda char: char in valid, data))
    except: 
        return data
    else: 
        return int(''.join(filter(lambda char: char in valid, data)))
product_categories['Failed Batches'] = product_categories['Failed Batches'].apply(makeFloat)
product_categories['Failed Batches'] = product_categories['Failed Batches'].astype('int')

# Remove specific string from 'Category' strings
def stringRemove(data, string):
    try: 
        data.replace(string,'')
    except: 
        return data
    else: 
        return data.replace(string,'')
product_categories['Category'] = product_categories['Category'].apply(stringRemove, args=':')
product_categories['Category'] = product_categories['Category'].apply(stringRemove, args=',')


# Calculated columns
product_categories['Percent Failed'] = 100* product_categories['Failed Batches'] / product_categories['Tested Batches']

# Aggregate for more normalizations
pc_totals_cols = ['Date', 'Tested Batches', 'Failed Batches']
pc_totals = product_categories[pc_totals_cols].groupby(by='Date').sum()/2
# Rename Aggregated Columns
pc_totals = removeCol(pc_totals, 'Failed Batches', newname='Total Failed')
pc_totals['Total Failed'] = pc_totals['Total Failed'].astype('int')
pc_totals = removeCol(pc_totals, 'Tested Batches', newname='Total Tested')
pc_totals['Total Tested'] = pc_totals['Total Tested'].astype('int')
# Merge with Category Data
product_categories = pc_totals.merge(product_categories, left_index=True, right_on='Date', how='right')
product_categories['Percent of Failures'] = 100 * product_categories['Failed Batches'] / product_categories['Total Failed']
product_categories['Percent Tested'] = 100 * product_categories['Tested Batches'] / product_categories['Total Tested']

# Save to file
print('Saving product_categories...')
product_categories.to_csv(path_or_buf='../../etl_data/product_categories.csv', index=False)

product_categories.head()
# Out:
# Saving product_categories...
#    Total Failed  Total Tested  Tested Batches       Date  \
# 0          3164         20797           10415 2018-11-13
# 1          3164         20797            6464 2018-11-13
# 2          3164         20797            3918 2018-11-13
# 3          3164         20797           20797 2018-11-13
# 0          4679         46503           23347 2019-04-29
#
#                                    Category  Failed Batches  Percent Failed  \
# 0                                    Flower            1029        9.879981
# 1        Inhalable\n(cartridges waxes etc.)            1054       16.305693
# 2  Other\n(edibles tinctures topicals etc.)            1081       27.590607
# 3                                     Total            3164       15.213733
# 0                                    Flower            1627        6.968775
#
#    Percent of Failures  Percent Tested
# 0            32.522124       50.079338
# 1            33.312263       31.081406
# 2            34.165613       18.839256
# 3           100.000000      100.000000
# 0            34.772387       50.205363

# %%
pc_totals.head()
# Out:
#             Total Failed  Total Tested
# Date
# 2018-10-09          2683         16049
# 2018-10-15          2804         16869
# 2018-10-22          2868         17833
# 2018-10-29          2985         18863
# 2018-11-05          3053         19707

# %%
# new_cols = ['Flower']
pc_pivot = product_categories.pivot(index='Date', columns='Category')
# May need to swap levels of hierarchical indeces if Tableau doesn't like this version
# pc_pivot.swaplevel(axis=1)

pc_pivot.to_csv(path_or_buf='../../etl_data/pc_pivot.csv', index=True)

pc_pivot.head()
# Out:
#            Total Failed                                     \
# Category         Flower Inhalable\n(cartridges waxes etc.)
# Date
# 2018-10-09         2683                               2683
# 2018-10-15         2804                               2804
# 2018-10-22         2868                               2868
# 2018-10-29         2985                               2985
# 2018-11-05         3053                               3053
#
#                                                           Total Tested  \
# Category   Other\n(edibles tinctures topicals etc.) Total       Flower
# Date
# 2018-10-09                                     2683  2683        16049
# 2018-10-15                                     2804  2804        16869
# 2018-10-22                                     2868  2868        17833
# 2018-10-29                                     2985  2985        18863
# 2018-11-05                                     3053  3053        19707
#
#                                                \
# Category   Inhalable\n(cartridges waxes etc.)
# Date
# 2018-10-09                              16049
# 2018-10-15                              16869
# 2018-10-22                              17833
# 2018-10-29                              18863
# 2018-11-05                              19707
#
#                                                            Tested Batches  \
# Category   Other\n(edibles tinctures topicals etc.)  Total         Flower
# Date
# 2018-10-09                                    16049  16049           7993
# 2018-10-15                                    16869  16869           8446
# 2018-10-22                                    17833  17833           8978
# 2018-10-29                                    18863  18863           9426
# 2018-11-05                                    19707  19707           9829
#
#                                                ...  \
# Category   Inhalable\n(cartridges waxes etc.)  ...
# Date                                           ...
# 2018-10-09                               4991  ...
# 2018-10-15                               5208  ...
# 2018-10-22                               5483  ...
# 2018-10-29                               5858  ...
# 2018-11-05                               6138  ...
#
#                                      Percent Failed             \
# Category   Other\n(edibles tinctures topicals etc.)      Total
# Date
# 2018-10-09                                29.853181  16.722741
# 2018-10-15                                29.362364  16.622206
# 2018-10-22                                28.736655  16.082544
# 2018-10-29                                28.248114  15.824630
# 2018-11-05                                27.700535  15.491957
#
#            Percent of Failures                                     \
# Category                Flower Inhalable\n(cartridges waxes etc.)
# Date
# 2018-10-09           31.792769                          34.103615
# 2018-10-15           32.738944                          33.594864
# 2018-10-22           32.531381                          33.682008
# 2018-10-29           32.428811                          33.701843
# 2018-11-05           32.459876                          33.606289
#
#                                                                  \
# Category   Other\n(edibles tinctures topicals etc.)       Total
# Date
# 2018-10-09                                34.103615  100.037272
# 2018-10-15                                33.666191  100.000000
# 2018-10-22                                33.786611  100.000000
# 2018-10-29                                33.869347  100.000000
# 2018-11-05                                33.933836  100.000000
#
#            Percent Tested                                     \
# Category           Flower Inhalable\n(cartridges waxes etc.)
# Date
# 2018-10-09      49.803726                          31.098511
# 2018-10-15      50.068172                          30.873199
# 2018-10-22      50.344866                          30.746369
# 2018-10-29      49.970842                          31.055505
# 2018-11-05      49.875679                          31.146293
#
#
# Category   Other\n(edibles tinctures topicals etc.)       Total
# Date
# 2018-10-09                                19.097763  100.006231
# 2018-10-15                                19.058628  100.000000
# 2018-10-22                                18.908765  100.000000
# 2018-10-29                                18.973652  100.000000
# 2018-11-05                                18.978028  100.000000
#
# [5 rows x 28 columns]

# %%
# Clean up fail_categories df

#Rename columns
fail_categories = removeCol(fail_categories, 'Failed Batches By Category', newname='Failed Batches')
fail_categories = removeCol(fail_categories, '*Reasons For Failure', newname='Failure Reason')

# Remove ':'
fail_categories['Failure Reason'] = fail_categories['Failure Reason'].apply(stringRemove, args=':')
# Remove '*'
# Revisit later
fail_categories['Failure Reason'] = fail_categories['Failure Reason'].apply(stringRemove, args='*')

# Convert 'Failed Batches' to int
fail_categories['Failed Batches'] = fail_categories['Failed Batches'].apply(makeFloat)
fail_categories['Failed Batches'] = fail_categories['Failed Batches'].astype('int')

# Calculated columns
# 'Total Failed'
fc_totals = fail_categories.groupby(by='Date').sum()/2
fc_totals = removeCol(fc_totals, 'Failed Batches', newname='Total Failed')
fc_totals['Total Failed'] = fc_totals['Total Failed'].astype('int')
fail_categories = fc_totals.merge(fail_categories, left_index=True, right_on='Date', how='right')
fail_categories['Percent of Failures'] = 100 * fail_categories['Failed Batches'] / fail_categories['Total Failed']

print('Saving fail_categories.csv...')
fail_categories.to_csv(path_or_buf='../../etl_data/fail_categories.csv', index=False)

fail_categories.dtypes
# Out:
# Saving fail_categories.csv...
# Total Failed                    int64
# Date                   datetime64[ns]
# Failed Batches                  int64
# Failure Reason                 object
# Percent of Failures           float64
# dtype: object

# %%
fail_categories.head()
# Out:
#    Total Failed       Date  Failed Batches        Failure Reason  \
# 0          3375 2018-11-13            2043          Label Claims
# 1          3375 2018-11-13             685            Pesticides
# 2          3375 2018-11-13             380  Microbial Impurities
# 3          3375 2018-11-13             171     Residual Solvents
# 4          3375 2018-11-13              35           Homogeneity
#
#    Percent of Failures
# 0            60.533333
# 1            20.296296
# 2            11.259259
# 3             5.066667
# 4             1.037037

# %%
fc_pivot = fail_categories.pivot(index='Date', columns='Failure Reason', values='Failed Batches')
fc_pivot = fc_pivot.fillna(0)
fc_pivot = fc_pivot.astype('int')
fc_pivot.head()
# Out:
# Failure Reason  Cannabinoids  Foreign Material  Heavy Metals  Homogeneity  \
# Date
# 2018-10-09                 0                10             0           35
# 2018-10-15                 0                10             0           35
# 2018-10-22                 0                10             0           35
# 2018-10-29                 0                10             0           35
# 2018-11-05                 0                10             0           35
#
# Failure Reason  Injurious to Human Health  Label Claims  Microbial Impurities  \
# Date
# 2018-10-09                              0          1751                   201
# 2018-10-15                              0          1823                   217
# 2018-10-22                              0          1867                   224
# 2018-10-29                              0          1953                   233
# 2018-11-05                              0          1979                   249
#
# Failure Reason  Moisture  Mycotoxins  Pesticides  Residual Solvents  Total  \
# Date
# 2018-10-09            40           0         602                130   2769
# 2018-10-15            45           0         632                137   2899
# 2018-10-22            45           0         645                145   2971
# 2018-10-29            45           0         663                154   3093
# 2018-11-05            50           0         672                167   3162
#
# Failure Reason  Water Activity
# Date
# 2018-10-09                   0
# 2018-10-15                   0
# 2018-10-22                   0
# 2018-10-29                   0
# 2018-11-05                   0

# %%
fail_reasons = [f for f in fail_categories['Failure Reason'].unique() if f != 'Total']
fail_reasons
# Out:
# ['Label Claims',
#  'Pesticides',
#  'Microbial Impurities',
#  'Residual Solvents',
#  'Homogeneity',
#  'Foreign Material',
#  'Moisture',
#  'Heavy Metals',
#  'Water Activity',
#  'Cannabinoids',
#  'Mycotoxins',
#  'Injurious to Human Health']

# %%
for f in fail_reasons:
    fc_pivot['Percent {}'.format(f)] = fc_pivot[f] / fc_pivot['Total']
fc_pivot.head()
# Out:
# Failure Reason  Cannabinoids  Foreign Material  Heavy Metals  Homogeneity  \
# Date
# 2018-10-09                 0                10             0           35
# 2018-10-15                 0                10             0           35
# 2018-10-22                 0                10             0           35
# 2018-10-29                 0                10             0           35
# 2018-11-05                 0                10             0           35
#
# Failure Reason  Injurious to Human Health  Label Claims  Microbial Impurities  \
# Date
# 2018-10-09                              0          1751                   201
# 2018-10-15                              0          1823                   217
# 2018-10-22                              0          1867                   224
# 2018-10-29                              0          1953                   233
# 2018-11-05                              0          1979                   249
#
# Failure Reason  Moisture  Mycotoxins  Pesticides  ...  \
# Date                                              ...
# 2018-10-09            40           0         602  ...
# 2018-10-15            45           0         632  ...
# 2018-10-22            45           0         645  ...
# 2018-10-29            45           0         663  ...
# 2018-11-05            50           0         672  ...
#
# Failure Reason  Percent Microbial Impurities  Percent Residual Solvents  \
# Date
# 2018-10-09                          0.072589                   0.046948
# 2018-10-15                          0.074853                   0.047258
# 2018-10-22                          0.075395                   0.048805
# 2018-10-29                          0.075331                   0.049790
# 2018-11-05                          0.078748                   0.052815
#
# Failure Reason  Percent Homogeneity  Percent Foreign Material  \
# Date
# 2018-10-09                 0.012640                  0.003611
# 2018-10-15                 0.012073                  0.003449
# 2018-10-22                 0.011781                  0.003366
# 2018-10-29                 0.011316                  0.003233
# 2018-11-05                 0.011069                  0.003163
#
# Failure Reason  Percent Moisture  Percent Heavy Metals  \
# Date
# 2018-10-09              0.014446                   0.0
# 2018-10-15              0.015523                   0.0
# 2018-10-22              0.015146                   0.0
# 2018-10-29              0.014549                   0.0
# 2018-11-05              0.015813                   0.0
#
# Failure Reason  Percent Water Activity  Percent Cannabinoids  \
# Date
# 2018-10-09                         0.0                   0.0
# 2018-10-15                         0.0                   0.0
# 2018-10-22                         0.0                   0.0
# 2018-10-29                         0.0                   0.0
# 2018-11-05                         0.0                   0.0
#
# Failure Reason  Percent Mycotoxins  Percent Injurious to Human Health
# Date
# 2018-10-09                     0.0                                0.0
# 2018-10-15                     0.0                                0.0
# 2018-10-22                     0.0                                0.0
# 2018-10-29                     0.0                                0.0
# 2018-11-05                     0.0                                0.0
#
# [5 rows x 25 columns]

# %%
fc_pivot.dtypes
# Out:
# Failure Reason
# Cannabinoids                           int64
# Foreign Material                       int64
# Heavy Metals                           int64
# Homogeneity                            int64
# Injurious to Human Health              int64
# Label Claims                           int64
# Microbial Impurities                   int64
# Moisture                               int64
# Mycotoxins                             int64
# Pesticides                             int64
# Residual Solvents                      int64
# Total                                  int64
# Water Activity                         int64
# Percent Label Claims                 float64
# Percent Pesticides                   float64
# Percent Microbial Impurities         float64
# Percent Residual Solvents            float64
# Percent Homogeneity                  float64
# Percent Foreign Material             float64
# Percent Moisture                     float64
# Percent Heavy Metals                 float64
# Percent Water Activity               float64
# Percent Cannabinoids                 float64
# Percent Mycotoxins                   float64
# Percent Injurious to Human Health    float64
# dtype: object
